# %%
f=open("demo1.txt","r")
data=f.read()
print(data)
f.close()
# Out:
# hii hello bye

# %%
f=open("demo2.txt","w")
f.write("hii hello")
#a=f.read() give error no redable in w
print(a)
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-9-7392de1d681f> in <module>
#       1 f=open("demo2.txt","w")
#       2 f.write("hii hello")
# ----> 3 a=f.read()
#       4 print(a)
#
# UnsupportedOperation: not readable

# %%
f=open("demo2.txt","w+")#seek use kari starting ma pointer laijavanu pachhi print karvanu jo em nam kariae to blank aave
a=f.read()
f.write("hii hello")
print(a)
f.close()

# %%
f=open("demo2.txt")
f.seek(0)
a=f.read()
print(a)
# Out:
# hii hello

# %%
f=open("abc.txt","w+")
n=input("enter string:")
f.write(n)
f.seek(0)
a=f.read()
print(a)
# Out:
# enter string:hii
# hii

# %%
f=open("demo3.txt","w+")
f.write("hii hello")
f.seek(0)
a=f.read()
z=a.upper()
print(z)
f.close()
# Out:
# HII HELLO

# %%
f=open("demo3.txt","w+")
f.write("hii hello")
f.seek(0)
a=f.read()
z=a[::-1]
print("demo3",z)
b=open("demo4.txt","w+")
b.write(z)
b.seek(0)
c=b.read()
print(c)
# Out:
# olleh iih
# olleh iih

# %%
f=open("demo5.txt","w+")
f.write("hii hello bye")
f.seek(0)
a=f.read()
a=a.split(" ")
for i in a:
    z=i[0].upper()+i[1:-1]+i[-1].upper()
    j=z.join("")
    print(z,end=" ")
b=open("demo6.txt","w+")
b.write()
b.seek(0)
c=b.read()
print(c)
# Out:
# HiI HellO ByE

# %%
f=open("countoflinewords.txt","w+")
f.write("hii hello bye")
f.seek(0)
a=f.read()
c=0
for i in a:
    c=c+1
print(c)
# Out:
# 13

# %%
f=open("countofline.txt","r")
#f.seek(0)
a=f.read()
print(a)
