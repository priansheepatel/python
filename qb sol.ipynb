# %%
#Create a Pandas DataFrame from the following table and write code to remove all rows from this table containing at least one 
#NaN value
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/patelmanishv/Sem4Data/refs/heads/main/Datasets/salesdata.csv")
print(df)
# Out:
#     Unnamed: 0     name region    sales  expenses
# 0            0  William    NaN  50000.0   42000.0
# 1            1     Emma  North  52000.0   43000.0
# 2            2    Sofia   East      NaN       NaN
# 3            3   Markus    NaN      NaN       NaN
# 4            4   Edward   West  42000.0   38000.0
# 5            5   Thomas   West  72000.0   39000.0
# 6            6    Ethan  South  49000.0   42000.0
# 7            7      NaN    NaN      NaN       NaN
# 8            8     Arun   West  67000.0   39000.0
# 9            9    Anika   East  65000.0   50000.0
# 10          10    Paulo  South  67000.0   45000.0

# %%
df.dropna(how="any")
print(df)
# Out:
#     Unnamed: 0     name region    sales  expenses
# 0            0  William    NaN  50000.0   42000.0
# 1            1     Emma  North  52000.0   43000.0
# 2            2    Sofia   East      NaN       NaN
# 3            3   Markus    NaN      NaN       NaN
# 4            4   Edward   West  42000.0   38000.0
# 5            5   Thomas   West  72000.0   39000.0
# 6            6    Ethan  South  49000.0   42000.0
# 7            7      NaN    NaN      NaN       NaN
# 8            8     Arun   West  67000.0   39000.0
# 9            9    Anika   East  65000.0   50000.0
# 10          10    Paulo  South  67000.0   45000.0
#     Unnamed: 0     name region    sales  expenses
# 0            0  William    NaN  50000.0   42000.0
# 1            1     Emma  North  52000.0   43000.0
# 2            2    Sofia   East      NaN       NaN
# 3            3   Markus    NaN      NaN       NaN
# 4            4   Edward   West  42000.0   38000.0
# 5            5   Thomas   West  72000.0   39000.0
# ...

# %%
df.dropna(how="all")
print(df)
# Out:
#     Unnamed: 0     name region    sales  expenses
# 0            0  William    NaN  50000.0   42000.0
# 1            1     Emma  North  52000.0   43000.0
# 2            2    Sofia   East      NaN       NaN
# 3            3   Markus    NaN      NaN       NaN
# 4            4   Edward   West  42000.0   38000.0
# 5            5   Thomas   West  72000.0   39000.0
# 6            6    Ethan  South  49000.0   42000.0
# 7            7      NaN    NaN      NaN       NaN
# 8            8     Arun   West  67000.0   39000.0
# 9            9    Anika   East  65000.0   50000.0
# 10          10    Paulo  South  67000.0   45000.0

# %%
#59  Consider the following data:
#  data = {
#     "A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
#     "B": [50, 40, 40, 30, 50],
#     "C": [True, False, False, False, True]
#  }
#  Convert this to a Pandas DataFrame and remove duplicate rows from it. Reset index values

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {"A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
        "B": [50, 40, 40, 30, 50],
        "C": [True, False, False, False, True]}
df=pd.DataFrame(data)
df
# Out:
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 2  TeamB  40  False
# 3  TeamC  30  False
# 4  TeamA  50   True

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 3  TeamC  30  False

# %%
df.drop_duplicates().reset_index[drop=True]
df
# Out:
#   File "<ipython-input-31-4bf1694409f2>", line 1
#     df.drop_duplicates().reset_index[drop=True]
#                                          ^
# SyntaxError: invalid syntax

# %%
# Consider the following autompg dataset:
# https://raw.githubusercontent.com/Jovita7/Data-Analysis-and-Visualization/main/auto-mpg.csv
 #Write Python code to convert it to a DataFrame and remove mpg and cylinders columns from i
data=pd.read_csv("https://raw.githubusercontent.com/Jovita7/Data-Analysis-and-Visualization/main/auto-mpg.csv")
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.drop(columns=["mpg","cylinders"],axis=1)
# Out:
#      displacement horsepower  weight  acceleration  model year  origin  \
# 0           307.0        130    3504          12.0          70       1
# 1           350.0        165    3693          11.5          70       1
# 2           318.0        150    3436          11.0          70       1
# 3           304.0        150    3433          12.0          70       1
# 4           302.0        140    3449          10.5          70       1
# ..            ...        ...     ...           ...         ...     ...
# 393         140.0         86    2790          15.6          82       1
# 394          97.0         52    2130          24.6          82       2
# 395         135.0         84    2295          11.6          82       1
# 396         120.0         79    2625          18.6          82       1
# 397         119.0         82    2720          19.4          82       1
#
#                       car name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# ...

# %%
# Use the file heights_weights.csv (https://raw.githubusercontent.com/Jovita7/Data-Analysis-and
# Visualization/main/heights_weights.csv) which contains 10000 non-null values for heights and weights. The Male column shows 
# 1 if the person is a Male and 0 if the person is a Female. 
# 1.        Convert this file into a pandas Data Frame. (0.5 marks)
#  2.        Display basic information like memory and data types for this data frame. (0.5 marks)
#  3.        Display basic statistics like mean, std, quartiles, etc. for this data frame. (0.5 marks)
#  4.        Create a correlation table for the data frame and comment about what kind of correlation is there between Height and 
# Weight. (0.5 marks)
#  5.        Do Height and Weight contain any outliers? (1 mark)
data=pd.read_csv("https://raw.githubusercontent.com/patelmanishv/Sem4Data/refs/heads/main/Datasets/heights_weights.csv")
data
# Out:
#          Height      Weight  Male
# 0     73.847017  241.893563     1
# 1     68.781904  162.310473     1
# 2     74.110105  212.740856     1
# 3     71.730978  220.042470     1
# 4     69.881796  206.349801     1
# ...         ...         ...   ...
# 9995  66.172652  136.777454     0
# 9996  67.067155  170.867906     0
# 9997  63.867992  128.475319     0
# 9998  69.034243  163.852461     0
# 9999  61.944246  113.649103     0
#
# [10000 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  10000 non-null  float64
#  1   Weight  10000 non-null  float64
#  2   Male    10000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 234.5 KB

# %%
data.describe()
# Out:
#              Height        Weight          Male
# count  10000.000000  10000.000000  10000.000000
# mean      66.367560    161.440357      0.500000
# std        3.847528     32.108439      0.500025
# min       54.263133     64.700127      0.000000
# 25%       63.505620    135.818051      0.000000
# 50%       66.318070    161.212928      0.500000
# 75%       69.174262    187.169525      1.000000
# max       78.998742    269.989699      1.000000

# %%
#numeric_only=True
data.corr()
# Out:
#           Height    Weight      Male
# Height  1.000000  0.924756  0.691072
# Weight  0.924756  1.000000  0.796723
# Male    0.691072  0.796723  1.000000

# %%
plt.boxplot(data["Height"])
plt.title("box plot Height")
plt.show()

# %%
plt.boxplot(data["Weight"])
plt.title("box plot Height")
plt.show()

# %%
# 62 Use the file ipl-matches.csv which contains data of all the IPL matches from year 2008 to 2022. Read this csv file and display the 
# basic information like memory and data types for this data frame. Write python code for the following cases:
#  1. List out all matches gone in superover.
#  2. How Many Matches won by Chennai Super Kings at Kolkata.
#  3. In How Many Matches MS Dhoni is Player of Match Vs Mumbai Indians.
#  4. Display list of all matches in which Gujarat Titans won the Toss and Elected to Bat and won the match.
#  5. Display list of all matches won by Gujarat Titans.
d=pd.read_csv("https://raw.githubusercontent.com/patelmanishv/Sem4Data/refs/heads/main/Datasets/ipl-matches.csv")
d
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
print(d.to_string())
# Out:
#           ID            City        Date   Season         MatchNumber                        Team1                        Team2                                                 Venue                   TossWinner TossDecision SuperOver                  WinningTeam      WonBy  Margin method    Player_of_Match                                                                                                                                                                 Team1Players                                                                                                                                                                    Team2Players                Umpire1                Umpire2
# ...

# %%
print(d.shape)

d[d["SuperOver"]=="Y"]
# Out:
# (950, 20)
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
d[d["WinningTeam"]=="Chennai Super Kings"]
# Out:
#           ID         City        Date   Season MatchNumber  \
# 19   1304101  Navi Mumbai  2022-05-08     2022          55
# 28   1304092         Pune  2022-05-01     2022          46
# 41   1304079  Navi Mumbai  2022-04-21     2022          33
# 52   1304068       Mumbai  2022-04-12     2022          22
# 74   1254117        Dubai  2021-10-15     2021       Final
# ..       ...          ...         ...      ...         ...
# 921   336009        Delhi  2008-05-08  2007/08          28
# 935   335996    Bangalore  2008-04-28  2007/08          15
# 938   335993      Chennai  2008-04-26  2007/08          11
# 942   335989      Chennai  2008-04-23  2007/08           8
# 948   335983   Chandigarh  2008-04-19  2007/08           2
#
#                            Team1                        Team2  \
# 19           Chennai Super Kings               Delhi Capitals
# 28           Chennai Super Kings          Sunrisers Hyderabad
# 41                Mumbai Indians          Chennai Super Kings
# ...

# %%
len(d[d["WinningTeam"]=="Chennai Super Kings"])
# Out:
# 121

# %%
d[(d["WinningTeam"]=="Chennai Super Kings")&(d["City"]=="Kolkata")]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
d[(d["WinningTeam"]=="Chennai Super Kings")&(d["City"]=="Kolkata")&(d["Player_of_Match"]=="MS Dhoni")]
# Out:
#          ID     City        Date   Season MatchNumber                  Team1  \
# 827  419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
#
#                    Team2         Venue           TossWinner TossDecision  \
# 827  Chennai Super Kings  Eden Gardens  Chennai Super Kings          bat
#
#     SuperOver          WinningTeam WonBy  Margin method Player_of_Match  \
# 827         N  Chennai Super Kings  Runs    55.0    NaN        MS Dhoni
#
#                                           Team1Players  \
# 827  ['BJ Hodge', 'MK Tiwary', 'SC Ganguly', 'WP Sa...
#
#                                           Team2Players          Umpire1  \
# 827  ['M Vijay', 'ML Hayden', 'SK Raina', 'S Badrin...  HDPK Dharmasena
#
#        Umpire2
# 827  AM Saheba
